# %%
from ExcitonBSE import ExcitonMoS2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
N=36 # Exciton Hamiltonian mesh

# %%
gamma=np.array([0.,0.,0.])
M=np.array([0,-0.5,0.])
K=np.array([0.33,-0.33,0.])
kpoints=[];N1=int(N/2);N2=int(N1/2);
for i in range(N1):
    kpoints.append(i*M/N1+(N1-i)*gamma/N1)
for i in range(N2):
    kpoints.append(i*K/N2+(N2-i)*M/N2)
kpoints.append(K)
kpoints=np.array(kpoints);kpoints=np.array(np.round(kpoints*N),dtype=np.int)

# %%
E=[]
for k in kpoints:
    Exciton=ExcitonMoS2()
    Exciton.constuctExcitonHamiltonian(epsilon=2.5,N=N,vb=[6],cb=[7],shift=0.45,Q=k)
    Exciton.solveExcitonHamiltonian()
    E.append(Exciton.EH)
    print(k,Exciton.EH[:4])
E=np.array(E)
# Out:
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [0 0 0] [1.91124271 1.91177379 2.06866599 2.07014843]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -1  0] [1.92222621 1.94478417 2.07836751 2.07978116]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -2  0] [1.95383381 1.97346894 2.10902912 2.11049346]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -3  0] [2.0024582  2.030162   2.15306362 2.15456959]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -4  0] [2.0628898  2.08191604 2.20379942 2.20536368]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -5  0] [2.12888756 2.15254967 2.23143369 2.24264744]
# Exciton Hamiltonian size: 1296X1296
# Construction Done!
# Hamiltonian Solved!
# [ 0 -6  0] [2.18385091 2.18652162 2.20015409 2.2188215 ]
# ...

# %%
plt.figure()
for i in range(100):
    plt.plot(E[:,i],'-+',color='blue')
plt.plot(np.ones(50)*(N1),np.linspace(0,3),'-',color='green')
plt.plot(np.ones(50)*(N1+N2),np.linspace(0,3),'-',color='green')
plt.xticks([0,N1,N1+N2],['$\Gamma$','M','K'])
plt.plot(np.linspace(0,300),np.ones(50)*E[0,0],'--',color='black')
plt.xlim([0.,N1+N2])
plt.ylim([1.85,2.35])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1.85, 2.35)
