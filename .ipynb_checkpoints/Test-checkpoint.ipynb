# %%
from ExcitonBSEKeldysh import ExcitonMoS2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Solve optical exciton problem

# %%
Exciton=ExcitonMoS2(epsilon=1,N=30,vb=[12,13],cb=[14,15],spin_orbit=True)
# Exciton.constuctExcitonHamiltonian(Q=[0,0,0])
# Exciton.solveExcitonHamiltonian(save=False)
# Out:
# Exciton Hamiltonian size: 3600X3600

# %%
# %%time
Exciton.calculateAbsobtionSpectrum(eta=0.01,n_iter=40,omega_n=5000)
# Out:
# CPU times: user 6.87 s, sys: 130 ms, total: 7 s
# Wall time: 941 ms

# %%
E,D=np.linalg.eigh(Exciton.HH)

# %%
optical=np.zeros(Exciton.NH)
P=np.array([Exciton.dx[indx] for indx in Exciton.indexes])
P/=np.linalg.norm(P)
for i in range(Exciton.NH):
    optical[i]=np.abs(np.sum(P*D[:,i].conj()))**2
omega_max=5;eta=0.02
omega_n=5000
omega=np.linspace(0,omega_max,omega_n+1);omega=np.delete(omega,0)
absorbtion=np.zeros(omega.size,dtype=np.complex)
for i in range(omega.size):
    absorbtion[i]=np.sum(optical/(omega[i]+1j*eta-E))
spectrum=-absorbtion.imag

# %%
plt.plot(omega,spectrum)
Exciton.plotAbsobtionSpectrum()
plt.xlim([1.5,3.5])
# Out:
# (1.5, 3.5)

# %%
Exciton.constuctExcitonHamiltonian(Q=[(1/3),(1/3),0],optic=False)
# Out:
# Construction Begin!
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-3-c1372c6fa78c> in <module>
# ----> 1 Exciton.constuctExcitonHamiltonian(Q=[(1/3),(1/3),0],optic=False)
#
# ~/Documents/GitHub/ExcitonBSE/ExcitonBSEKeldysh.py in constuctExcitonHamiltonian(self, Q, optic)
#     151             self.HH=FastExcitonHamiltonianOptical(HH,self.E,self.shift,self.D,self.W,self.indexes)
#     152         else:
# --> 153             self.HH=FastExcitonHamiltonian(HH,self.E,self.shift,self.D,self.W,self.V,self.indexes,self.Q)
#     154         print('Construction Done!')
#     155
#
# ~/.local/lib/python3.6/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     348                 e.patch_message(msg)
#     349
# --> 350             error_rewrite(e, 'typing')
#     351         except errors.UnsupportedError as e:
#     352             # Something unsupported is present in the user code, add help info
#
# ~/.local/lib/python3.6/site-packages/numba/dispatcher.py in error_rewrite(e, issue_type)
#     315                 raise e
#     316             else:
# --> 317                 reraise(type(e), e, None)
#     318
#     319         argtypes = []
#
# ~/.local/lib/python3.6/site-packages/numba/six.py in reraise(tp, value, tb)
#     656             value = tp()
#     657         if value.__traceback__ is not tb:
# --> 658             raise value.with_traceback(tb)
#     659         raise value
#     660
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Unknown attribute 'sum' of type (array(complex128, 1d, C), array(complex128, 1d, A))
#
# File "ExcitonBSEKeldysh.py", line 35:
# def FastExcitonHamiltonian(H,E,shift,D,W,V,indexes,q):
#     <source elided>
#
#         overlap_c=(D[(x1+q[0])%N,(y1+q[1])%N,:,c1].conjugate(),D[x1,y1,:,v1]).sum();
#         ^
#
# [1] During: typing of get attribute at /home/drg/Documents/GitHub/ExcitonBSE/ExcitonBSEKeldysh.py (35)
#
# File "ExcitonBSEKeldysh.py", line 35:
# def FastExcitonHamiltonian(H,E,shift,D,W,V,indexes,q):
#     <source elided>
#
#         overlap_c=(D[(x1+q[0])%N,(y1+q[1])%N,:,c1].conjugate(),D[x1,y1,:,v1]).sum();
#         ^
#
# This is not usually a problem with Numba itself but instead often caused by
# the use of unsupported features or an issue in resolving types.
#
# To see Python/NumPy features supported by the latest release of Numba visit:
# http://numba.pydata.org/numba-doc/dev/reference/pysupported.html
# and
# http://numba.pydata.org/numba-doc/dev/reference/numpysupported.html
#
# For more information about typing errors and how to debug them visit:
# http://numba.pydata.org/numba-doc/latest/user/troubleshoot.html#my-code-doesn-t-compile
#
# If you think your code should work with Numba, please report the error message
# and traceback, along with a minimal reproducer at:
# https://github.com/numba/numba/issues/new
